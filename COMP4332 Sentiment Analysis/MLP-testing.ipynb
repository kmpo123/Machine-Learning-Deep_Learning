# %% [markdown]
# ## Import Libraries

# %%
import os
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
ps = PorterStemmer()
import math
import pandas as pd
import numpy as np
from tensorflow import keras
import tensorflow as tf
import matplotlib.pyplot as plt
from collections import Counter
from itertools import chain
from sklearn.metrics import accuracy_score, f1_score
from keras.models import Sequential, Model
from keras.layers import Dense, Embedding, Dropout, BatchNormalization, Activation, Input, \
    Conv1D, MaxPool1D, Flatten, Concatenate, Add
from keras_layer_normalization import LayerNormalization
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

stopwords = set(stopwords.words("english"))
ps = PorterStemmer()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### A. Load the data

# %%
def load_data(split_name='train', columns=['text', 'stars']):
    try:
        print(f"select [{', '.join(columns)}] columns from the {split_name} split")
        df = pd.read_csv(f'data_2021_spring/{split_name}.csv')
        df = df.loc[:,columns]
        print("succeed!")
        return df
    except:
        print("Failed, then try to ")
        print(f"select all columns from the {split_name} split")
        df = pd.read_csv(f'data_2021_spring/{split_name}.csv')
        return df

# %%
train_df = load_data('train', columns='full')
# Out:
# select [f, u, l, l] columns from the train split
# Failed, then try to
# select all columns from the train split

# %% [markdown]
# ## 2. Preprocessing
#
# Preprocessing and feature engineering is important in machine learning

# %%
def lower(s):
    """
    :param s: a string.
    return a string with lower characters
    Note that we allow the input to be nested string of a list.
    e.g.
    Input: 'Text mining is to identify useful information.'
    Output: 'text mining is to identify useful information.'
    """
    if isinstance(s, list):
        return [lower(t) for t in s]
    if isinstance(s, str):
        return s.lower()
    else:
        raise NotImplementedError("unknown datatype")


def tokenize(text):
    """
    :param text: a doc with multiple sentences, type: str
    return a word list, type: list
    e.g.
    Input: 'Text mining is to identify useful information.'
    Output: ['Text', 'mining', 'is', 'to', 'identify', 'useful', 'information', '.']
    """
    return nltk.word_tokenize(text)


def stem(tokens):
    """
    :param tokens: a list of tokens, type: list
    return a list of stemmed words, type: list
    e.g.
    Input: ['Text', 'mining', 'is', 'to', 'identify', 'useful', 'information', '.']
    Output: ['text', 'mine', 'is', 'to', 'identifi', 'use', 'inform', '.']
    """
    ### equivalent code
    # results = list()
    # for token in tokens:
    #     results.append(ps.stem(token))
    # return results

    return [ps.stem(token) for token in tokens]

def n_gram(tokens, n=1):
    """
    :param tokens: a list of tokens, type: list
    :param n: the corresponding n-gram, type: int
    return a list of n-gram tokens, type: list
    e.g.
    Input: ['text', 'mine', 'is', 'to', 'identifi', 'use', 'inform', '.'], 2
    Output: ['text mine', 'mine is', 'is to', 'to identifi', 'identifi use', 'use inform', 'inform .']
    """
    if n == 1:
        return tokens
    else:
        results = list()
        for i in range(len(tokens)-n+1):
            # tokens[i:i+n] will return a sublist from i th to i+n th (i+n th is not included)
            results.append(" ".join(tokens[i:i+n]))
        return results

def filter_stopwords(tokens):
    """
    :param tokens: a list of tokens, type: list
    return a list of filtered tokens, type: list
    e.g.
    Input: ['text', 'mine', 'is', 'to', 'identifi', 'use', 'inform', '.']
    Output: ['text', 'mine', 'identifi', 'use', 'inform', '.']
    """
    ### equivalent code
    # results = list()
    # for token in tokens:
    #     if token not in stopwords and not token.isnumeric():
    #         results.append(token)
    # return results

    return [token for token in tokens if token not in stopwords and not token.isnumeric()]

import numpy as np

def get_feats_dict(feats, min_freq=-1, max_freq=-1, max_size=-1):
    """
    :param data: a list of features, type: list(list)
    :param min_freq: the lowest fequency that the fequency of a feature smaller than it will be filtered out, type: int
    :param max_freq: the highest fequency that the fequency of a feature larger than it will be filtered out, type: int
    :param max_size: the max size of feature dict, type: int
    return a feature dict that maps features to indices, sorted by frequencies
    # Counter document: https://docs.python.org/3.6/library/collections.html#collections.Counter
    """
    # count all features
    feat_cnt = Counter(feats) # ["text", "text", "mine"] --> {"text": 2, "mine": 1}
    if max_size > 0 and min_freq == -1 and max_freq == -1:
        valid_feats = [f for f, cnt in feat_cnt.most_common(max_size)]
    else:
        valid_feats = list()
        for f, cnt in feat_cnt.most_common():
            if (min_freq == -1 or cnt >= min_freq) and \
                (max_freq == -1 or cnt <= max_freq):
                valid_feats.append(f)
    if max_size > 0 and len(valid_feats) > max_size:
        valid_feats = valid_feats[:max_size]        
    print("Size of features:", len(valid_feats))
    
    # build a mapping from features to indices
    feats_dict = dict(zip(valid_feats, range(len(valid_feats))))
    return feats_dict

def get_onehot_vector(feats, feats_dict):
    """
    :param feats: a list of features, type: list
    :param feats_dict: a dict from features to indices, type: dict
    return a feature vector,
    """
    # initialize the vector as all zeros
    vector = np.zeros(len(feats_dict), dtype=np.float)
    for f in feats:
        # get the feature index, return -1 if the feature is not existed
        f_idx = feats_dict.get(f, -1)
        if f_idx != -1:
            # set the corresponding element as 1
            vector[f_idx] = 1
    return vector

# %%
train_df = load_data('train', columns='full')
valid_df = load_data('valid', columns='full')


train_ids = train_df['review_id']
train_texts = train_df['text']
train_labels = train_df['stars']

test_ids = valid_df['review_id']
test_texts = valid_df['text']
test_labels = valid_df['stars']




# extract features
train_tokens = [tokenize(text) for text in train_texts]
test_tokens = [tokenize(text) for text in test_texts]

train_stemmed = [stem(tokens) for tokens in train_tokens]
test_stemmed = [stem(tokens) for tokens in test_tokens]

train_stemmed = [filter_stopwords(tokens) for tokens in train_stemmed]
test_stemmed = [filter_stopwords(tokens) for tokens in test_stemmed]

train_2_gram = [n_gram(tokens, 2) for tokens in train_stemmed]
train_3_gram = [n_gram(tokens, 3) for tokens in train_stemmed]
test_2_gram = [n_gram(tokens, 2) for tokens in test_stemmed]
test_3_gram = [n_gram(tokens, 3) for tokens in test_stemmed]

# build the feature list
train_feats = list()
for i in range(len(train_ids)):
    train_feats.append(
        train_stemmed[i] + train_2_gram[i] + train_3_gram[i])
test_feats = list()
for i in range(len(test_ids)):
    test_feats.append(
        test_stemmed[i] + test_2_gram[i] + test_3_gram[i])

# build a mapping from features to indices
feats_dict = get_feats_dict(
    chain.from_iterable(train_feats),
    min_freq=5)

# build the feats_matrix
# convert each example to a ont-hot vector, and then stack vectors as a matrix
train_feats_matrix = np.vstack(
    [get_onehot_vector(f, feats_dict) for f in train_feats])
test_feats_matrix = np.vstack(
    [get_onehot_vector(f, feats_dict) for f in test_feats])

# convert labels to label_matrix
num_classes = max(train_labels)
# convert each label to a ont-hot vector, and then stack vectors as a matrix
train_label_matrix = keras.utils.to_categorical(train_labels-1, num_classes=num_classes)
test_label_matrix = keras.utils.to_categorical(test_labels-1, num_classes=num_classes)
# Out:
# select [f, u, l, l] columns from the train split
# Failed, then try to
# select all columns from the train split
# select [f, u, l, l] columns from the valid split
# Failed, then try to
# select all columns from the valid split
# Size of features: 39838

# %%
# first, build a Counter for stemmed features, e.g., {"text": 2, "mine": 1}
stemmed_feat_cnt = Counter()
for feats in train_stemmed:
    stemmed_feat_cnt.update(feats)
print("stemmed feature size:", len(stemmed_feat_cnt))

# then, get the sorted features by the frequency
stemmed_feat_keys = [f for f, cnt in stemmed_feat_cnt.most_common()]

# draw linear lines and log lines for sorted features
# set the figure size
plt.figure(figsize=(10,4))
# generate two subfigures and set current as the first one
plt.subplot(1,2,1)
# draw linear lines
plt.plot(range(1, len(stemmed_feat_cnt)+1),
         [stemmed_feat_cnt[f] for f in stemmed_feat_keys])
# set labels
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
# set current as the second one
plt.subplot(1,2,2)
# draw log lines
plt.loglog(range(1, len(stemmed_feat_cnt)+1),
           [stemmed_feat_cnt[f] for f in stemmed_feat_keys],
           basex=10, basey=10)
# set labels
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
plt.show()
# Out:
# stemmed feature size: 24119
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.

# %%
# build Counters for 2-gram features and 3-gram features
bi_gram_feat_cnt = Counter()
for feats in train_2_gram:
    bi_gram_feat_cnt.update(feats)
    
tri_gram_feat_cnt = Counter()
for feats in train_3_gram:
    tri_gram_feat_cnt.update(feats)

# then, get the sorted features by the frequency
bi_gram_feat_keys = [f for f, cnt in bi_gram_feat_cnt.most_common()]
tri_gram_feat_keys = [f for f,cnt in tri_gram_feat_cnt.most_common()]

# draw linear lines and log lines for sorted features
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
# put the four linear lines together
plt.plot(range(1, len(stemmed_feat_cnt)+1),
         [stemmed_feat_cnt[f] for f in stemmed_feat_keys],
         label="stemmed")
plt.plot(range(1, len(bi_gram_feat_cnt)+1),
         [bi_gram_feat_cnt[f] for f in bi_gram_feat_keys],
         label="2-gram")
plt.plot(range(1, len(tri_gram_feat_cnt)+1),
         [tri_gram_feat_cnt[f] for f in tri_gram_feat_keys],
         label="3-gram")
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
# show the legend
plt.legend()
plt.subplot(1,2,2)
# put the four log lines together
plt.loglog(range(1, len(stemmed_feat_cnt)+1),
         [stemmed_feat_cnt[f] for f in stemmed_feat_keys],
           basex=10, basey=10, label="stemmed")
plt.loglog(range(1, len(bi_gram_feat_cnt)+1),
         [bi_gram_feat_cnt[f] for f in bi_gram_feat_keys],
           basex=10, basey=10, label="2-gram")
plt.loglog(range(1, len(tri_gram_feat_cnt)+1),
         [tri_gram_feat_cnt[f] for f in tri_gram_feat_keys],
           basex=10, basey=10, label="3-gram")
plt.xlabel("Feature Index")
plt.ylabel("Feature Frequency")
# show the legend
plt.legend()
plt.show()

print("stemmed feature size:", len(stemmed_feat_cnt))
print("2-gram feature size:", len(bi_gram_feat_cnt))
print("3-gram feature size:", len(tri_gram_feat_cnt))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:35: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:35: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:38: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:38: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:41: MatplotlibDeprecationWarning: The 'basex' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:41: MatplotlibDeprecationWarning: The 'basey' parameter of __init__() has been renamed 'base' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
# stemmed feature size: 24119
# 2-gram feature size: 331339
# 3-gram feature size: 688795

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier

def build_MLP(input_size, output_size, num_layers, hidden_size,
              activation="relu",
              dropout_rate=0.0,
              batch_norm=False,
              layer_norm=False,
              l2_reg=0.0,
              loss="categorical_crossentropy",
              optimizer="SGD",
              learning_rate=0.1,
              metric="accuracy"):

    model = Sequential()
    
    if num_layers == 1:
        model.add(Dense(output_size,
                        activation="softmax",
                        input_dim=input_size,
                        kernel_initializer=keras.initializers.he_normal(seed=0),   #normal distribution initializer
                        bias_initializer="zeros",
                        kernel_regularizer=keras.regularizers.l2(l2_reg)))
    else:
        for i in range(num_layers-1):
            if i == 0:
                # fitst layer: input -> hidden
                model.add(Dense(hidden_size,
                                input_dim=input_size,
                                kernel_initializer=keras.initializers.he_normal(seed=0),
                                bias_initializer="zeros",
                                kernel_regularizer=keras.regularizers.l2(l2_reg)))
            else:
                # hidden layers: hidden -> hidden
                model.add(Dense(hidden_size,
                                input_dim=hidden_size,
                                kernel_initializer=keras.initializers.he_normal(seed=0),
                                bias_initializer="zeros",
                                kernel_regularizer=keras.regularizers.l2(l2_reg)))
            # add layer_norm
            if layer_norm:
                model.add(LayerNormalization())
            # add batch_norm
            if batch_norm:
                model.add(BatchNormalization())
            # add activation
            model.add(Activation(activation))
            # add dropout here (set seed as 0 in order to reproduce)
            if dropout_rate > 0.0:
                model.add(Dropout(dropout_rate, seed=0))
        # last layer: hidden -> class
        model.add(Dense(output_size,
                        activation="softmax",
                        input_dim=hidden_size,
                        kernel_initializer=keras.initializers.he_normal(seed=0),
                        bias_initializer="zeros"))
    
    # set the loss, the optimizer, and the metric
    if optimizer == "SGD":
        optimizer = keras.optimizers.SGD(lr=learning_rate)
    elif optimizer == "RMSprop":
        optmizer = keras.optimizers.RMSprop(learning_rate=learning_rate)
    elif optimizer == "Adam":
        optmizer = keras.optimizers.Adam(learning_rate=learning_rate)
    else:
        raise NotImplementedError
    model.compile(loss=loss, optimizer=optimizer, metrics=[metric])
    
    return model

# %%
def create_model(optimizer='SGD', lr = 0.1, dr = 0.0,layer = 3, h_size = 200):
    model = build_MLP(input_size=len(feats_dict), output_size=num_classes,
                      num_layers=layer, hidden_size=h_size,
                      optimizer=optimizer, learning_rate=lr, dropout_rate = dr)
    return model

np.random.seed(0)
tf.random.set_seed(0)

#create the model with the best epoch and batch size found in last step
model = KerasClassifier(build_fn=create_model, epochs=50, batch_size=5, verbose=0)

# difine grid search parameter 
optimizer = ['SGD', 'RMSprop',  'Adam']
lr = [0.01,0.1]
dr = [0.01, 0.1]
layer = [2,4]
h_size = [100, 200]
batch_size = [8,16]
epochs = [2, 5]
param_grid = dict(optimizer=optimizer, 
                  lr=lr,
                  batch_size=batch_size, epochs=epochs,
                  h_size= h_size,
                 layer = layer,
                  dr=dr
                 )
grid = GridSearchCV(estimator=model, param_grid=param_grid,verbose=70,cv=2)
grid_result = grid.fit(train_feats_matrix, train_label_matrix)

# grid searching result
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 2 folds for each of 192 candidates, totalling 384 fits
# [CV 1/2; 1/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 1/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time=  33.3s
# [CV 2/2; 1/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 1/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time=  28.4s
# [CV 1/2; 2/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 1/2; 2/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time=  41.6s
# [CV 2/2; 2/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 2/2; 2/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time=  42.7s
# [CV 1/2; 3/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 1/2; 3/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time=  32.9s
# [CV 2/2; 3/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 2/2; 3/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time=  35.9s
# [CV 1/2; 4/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 1/2; 4/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time=  28.7s
# [CV 2/2; 4/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 2/2; 4/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time=  26.7s
# [CV 1/2; 5/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 1/2; 5/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time=  46.5s
# [CV 2/2; 5/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 2/2; 5/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time=  49.7s
# [CV 1/2; 6/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 1/2; 6/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time=  38.1s
# [CV 2/2; 6/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 2/2; 6/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time=  33.9s
# [CV 1/2; 7/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 1/2; 7/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time=  31.6s
# [CV 2/2; 7/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 2/2; 7/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time=  25.2s
# [CV 1/2; 8/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 1/2; 8/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time=  42.5s
# [CV 2/2; 8/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 2/2; 8/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time=  49.5s
# [CV 1/2; 9/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 1/2; 9/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time=  37.4s
# [CV 2/2; 9/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 2/2; 9/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time=  42.2s
# [CV 1/2; 10/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 1/2; 10/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time=  26.0s
# [CV 2/2; 10/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 2/2; 10/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time=  30.7s
# [CV 1/2; 11/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 1/2; 11/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time=  48.5s
# [CV 2/2; 11/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 2/2; 11/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time=  51.1s
# [CV 1/2; 12/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 1/2; 12/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time=  38.8s
# [CV 2/2; 12/192] START batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 2/2; 12/192] END batch_size=8, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time=  36.5s
# [CV 1/2; 13/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 13/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time=  43.7s
# [CV 2/2; 13/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 13/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time=  45.2s
# [CV 1/2; 14/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=RMSprop
# [CV 1/2; 14/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=RMSprop; total time= 1.1min
# [CV 2/2; 14/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=RMSprop
# [CV 2/2; 14/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=RMSprop; total time= 1.1min
# [CV 1/2; 15/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=Adam
# [CV 1/2; 15/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=Adam; total time=  57.9s
# [CV 2/2; 15/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=Adam
# [CV 2/2; 15/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=Adam; total time=  59.1s
# [CV 1/2; 16/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=SGD
# [CV 1/2; 16/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=SGD; total time=  49.5s
# [CV 2/2; 16/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=SGD
# [CV 2/2; 16/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=SGD; total time=  49.5s
# [CV 1/2; 17/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=RMSprop
# [CV 1/2; 17/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=RMSprop; total time= 1.2min
# [CV 2/2; 17/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=RMSprop
# [CV 2/2; 17/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=RMSprop; total time= 1.2min
# [CV 1/2; 18/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=Adam
# [CV 1/2; 18/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=Adam; total time=  56.2s
# [CV 2/2; 18/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=Adam
# [CV 2/2; 18/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=Adam; total time=  52.1s
# [CV 1/2; 19/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=SGD
# [CV 1/2; 19/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=SGD; total time=  44.7s
# [CV 2/2; 19/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=SGD
# [CV 2/2; 19/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=SGD; total time=  44.1s
# [CV 1/2; 20/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=RMSprop
# [CV 1/2; 20/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=RMSprop; total time= 1.3min
# [CV 2/2; 20/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=RMSprop
# [CV 2/2; 20/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=RMSprop; total time= 1.2min
# [CV 1/2; 21/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=Adam
# [CV 1/2; 21/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=Adam; total time=  59.4s
# [CV 2/2; 21/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=Adam
# [CV 2/2; 21/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=Adam; total time=  57.7s
# [CV 1/2; 22/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=SGD
# [CV 1/2; 22/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=SGD; total time=  41.8s
# [CV 2/2; 22/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=SGD
# [CV 2/2; 22/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=SGD; total time=  46.9s
# [CV 1/2; 23/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=RMSprop
# [CV 1/2; 23/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=RMSprop; total time= 1.2min
# [CV 2/2; 23/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=RMSprop
# [CV 2/2; 23/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=RMSprop; total time= 1.3min
# [CV 1/2; 24/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=Adam
# [CV 1/2; 24/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=Adam; total time=  58.7s
# [CV 2/2; 24/192] START batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=Adam
# [CV 2/2; 24/192] END batch_size=8, dr=0.01, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=Adam; total time=  56.0s
# [CV 1/2; 25/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 25/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time= 1.1min
# [CV 2/2; 25/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 25/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time= 1.0min
# [CV 1/2; 26/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 1/2; 26/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time= 1.8min
# [CV 2/2; 26/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 2/2; 26/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time= 1.7min
# [CV 1/2; 27/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 1/2; 27/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time= 1.4min
# [CV 2/2; 27/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 2/2; 27/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time= 1.3min
# [CV 1/2; 28/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 1/2; 28/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time= 1.1min
# [CV 2/2; 28/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 2/2; 28/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time= 1.1min
# [CV 1/2; 29/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 1/2; 29/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time= 1.8min
# [CV 2/2; 29/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 2/2; 29/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time= 1.7min
# [CV 1/2; 30/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 1/2; 30/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time= 1.3min
# [CV 2/2; 30/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 2/2; 30/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time= 1.4min
# [CV 1/2; 31/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 1/2; 31/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time= 1.2min
# [CV 2/2; 31/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 2/2; 31/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time= 1.2min
# [CV 1/2; 32/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 1/2; 32/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time= 1.9min
# [CV 2/2; 32/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 2/2; 32/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time= 1.8min
# [CV 1/2; 33/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 1/2; 33/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time= 1.4min
# [CV 2/2; 33/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 2/2; 33/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time= 1.5min
# [CV 1/2; 34/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 1/2; 34/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time= 1.2min
# [CV 2/2; 34/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 2/2; 34/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time= 1.3min
# [CV 1/2; 35/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 1/2; 35/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time= 1.8min
# [CV 2/2; 35/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 2/2; 35/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time= 1.8min
# [CV 1/2; 36/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 1/2; 36/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time= 1.5min
# [CV 2/2; 36/192] START batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 2/2; 36/192] END batch_size=8, dr=0.01, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time= 1.5min
# [CV 1/2; 37/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 37/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time= 1.6min
# [CV 2/2; 37/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 37/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time= 1.7min
# [CV 1/2; 38/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=RMSprop
# [CV 1/2; 38/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=RMSprop; total time= 2.7min
# [CV 2/2; 38/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=RMSprop
# [CV 2/2; 38/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=RMSprop; total time= 2.8min
# [CV 1/2; 39/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=Adam
# [CV 1/2; 39/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=Adam; total time= 2.1min
# [CV 2/2; 39/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=Adam
# [CV 2/2; 39/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=Adam; total time= 2.1min
# [CV 1/2; 40/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=SGD
# [CV 1/2; 40/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=SGD; total time= 1.7min
# [CV 2/2; 40/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=SGD
# [CV 2/2; 40/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=SGD; total time= 1.7min
# [CV 1/2; 41/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=RMSprop
# [CV 1/2; 41/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=RMSprop; total time= 2.7min
# [CV 2/2; 41/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=RMSprop
# [CV 2/2; 41/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=RMSprop; total time= 2.7min
# [CV 1/2; 42/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=Adam
# [CV 1/2; 42/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=Adam; total time= 2.1min
# [CV 2/2; 42/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=Adam
# [CV 2/2; 42/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=Adam; total time= 2.1min
# [CV 1/2; 43/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=SGD
# [CV 1/2; 43/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=SGD; total time= 1.7min
# [CV 2/2; 43/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=SGD
# [CV 2/2; 43/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=SGD; total time= 1.7min
# [CV 1/2; 44/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=RMSprop
# [CV 1/2; 44/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=RMSprop; total time= 2.8min
# [CV 2/2; 44/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=RMSprop
# [CV 2/2; 44/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=RMSprop; total time= 2.8min
# [CV 1/2; 45/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=Adam
# [CV 1/2; 45/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=Adam; total time= 2.2min
# [CV 2/2; 45/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=Adam
# [CV 2/2; 45/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=Adam; total time= 2.3min
# [CV 1/2; 46/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=SGD
# [CV 1/2; 46/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=SGD; total time= 1.6min
# [CV 2/2; 46/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=SGD
# [CV 2/2; 46/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=SGD; total time= 1.7min
# [CV 1/2; 47/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=RMSprop
# [CV 1/2; 47/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=RMSprop; total time= 2.8min
# [CV 2/2; 47/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=RMSprop
# [CV 2/2; 47/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=RMSprop; total time= 3.0min
# [CV 1/2; 48/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=Adam
# [CV 1/2; 48/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=Adam; total time= 2.3min
# [CV 2/2; 48/192] START batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=Adam
# [CV 2/2; 48/192] END batch_size=8, dr=0.01, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=Adam; total time= 2.4min
# [CV 1/2; 49/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 49/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time=  27.0s
# [CV 2/2; 49/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 49/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time=  30.0s
# [CV 1/2; 50/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 1/2; 50/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time=  44.7s
# [CV 2/2; 50/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 2/2; 50/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time=  46.7s
# [CV 1/2; 51/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 1/2; 51/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time=  40.5s
# [CV 2/2; 51/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 2/2; 51/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time=  38.8s
# [CV 1/2; 52/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 1/2; 52/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time=  30.1s
# [CV 2/2; 52/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 2/2; 52/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time=  34.3s
# [CV 1/2; 53/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 1/2; 53/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time=  46.4s
# [CV 2/2; 53/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 2/2; 53/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time=  46.2s
# [CV 1/2; 54/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 1/2; 54/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time=  35.1s
# [CV 2/2; 54/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 2/2; 54/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time=  41.3s
# [CV 1/2; 55/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 1/2; 55/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time=  33.0s
# [CV 2/2; 55/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 2/2; 55/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time=  28.8s
# [CV 1/2; 56/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 1/2; 56/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time=  44.3s
# [CV 2/2; 56/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 2/2; 56/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time=  44.7s
# [CV 1/2; 57/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 1/2; 57/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time=  38.5s
# [CV 2/2; 57/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 2/2; 57/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time=  39.5s
# [CV 1/2; 58/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 1/2; 58/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time=  27.5s
# [CV 2/2; 58/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 2/2; 58/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time=  30.0s
# [CV 1/2; 59/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 1/2; 59/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time=  51.3s
# [CV 2/2; 59/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 2/2; 59/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time=  44.1s
# [CV 1/2; 60/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 1/2; 60/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time=  36.1s
# [CV 2/2; 60/192] START batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 2/2; 60/192] END batch_size=8, dr=0.1, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time=  37.4s
# [CV 1/2; 61/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 61/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time=  48.8s
# [CV 2/2; 61/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 61/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time=  46.6s
# [CV 1/2; 62/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=RMSprop
# [CV 1/2; 62/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=RMSprop; total time= 1.4min
# [CV 2/2; 62/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=RMSprop
# [CV 2/2; 62/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=RMSprop; total time= 1.2min
# [CV 1/2; 63/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=Adam
# [CV 1/2; 63/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=Adam; total time=  57.1s
# [CV 2/2; 63/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=Adam
# [CV 2/2; 63/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=Adam; total time=  56.9s
# [CV 1/2; 64/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=SGD
# [CV 1/2; 64/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=SGD; total time=  48.3s
# [CV 2/2; 64/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=SGD
# [CV 2/2; 64/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=SGD; total time=  46.2s
# [CV 1/2; 65/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=RMSprop
# [CV 1/2; 65/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=RMSprop; total time= 1.2min
# [CV 2/2; 65/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=RMSprop
# [CV 2/2; 65/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=RMSprop; total time= 1.2min
# [CV 1/2; 66/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=Adam
# [CV 1/2; 66/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=Adam; total time=  57.0s
# [CV 2/2; 66/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=Adam
# [CV 2/2; 66/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=2, lr=0.1, optimizer=Adam; total time=  59.6s
# [CV 1/2; 67/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=SGD
# [CV 1/2; 67/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=SGD; total time=  47.1s
# [CV 2/2; 67/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=SGD
# [CV 2/2; 67/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=SGD; total time=  45.1s
# [CV 1/2; 68/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=RMSprop
# [CV 1/2; 68/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=RMSprop; total time= 1.2min
# [CV 2/2; 68/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=RMSprop
# [CV 2/2; 68/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=RMSprop; total time= 1.2min
# [CV 1/2; 69/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=Adam
# [CV 1/2; 69/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=Adam; total time=  60.0s
# [CV 2/2; 69/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=Adam
# [CV 2/2; 69/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.01, optimizer=Adam; total time=  58.6s
# [CV 1/2; 70/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=SGD
# [CV 1/2; 70/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=SGD; total time=  44.7s
# [CV 2/2; 70/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=SGD
# [CV 2/2; 70/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=SGD; total time=  46.2s
# [CV 1/2; 71/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=RMSprop
# [CV 1/2; 71/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=RMSprop; total time= 1.2min
# [CV 2/2; 71/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=RMSprop
# [CV 2/2; 71/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=RMSprop; total time= 1.2min
# [CV 1/2; 72/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=Adam
# [CV 1/2; 72/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=Adam; total time= 1.1min
# [CV 2/2; 72/192] START batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=Adam
# [CV 2/2; 72/192] END batch_size=8, dr=0.1, epochs=2, h_size=200, layer=4, lr=0.1, optimizer=Adam; total time= 1.1min
# [CV 1/2; 73/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 73/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time= 1.1min
# [CV 2/2; 73/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 73/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time= 1.2min
# [CV 1/2; 74/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 1/2; 74/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time= 1.8min
# [CV 2/2; 74/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 2/2; 74/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time= 1.8min
# [CV 1/2; 75/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 1/2; 75/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time= 1.4min
# [CV 2/2; 75/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 2/2; 75/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time= 1.4min
# [CV 1/2; 76/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 1/2; 76/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time= 1.2min
# [CV 2/2; 76/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 2/2; 76/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time= 1.1min
# [CV 1/2; 77/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 1/2; 77/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time= 1.9min
# [CV 2/2; 77/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 2/2; 77/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time= 1.7min
# [CV 1/2; 78/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 1/2; 78/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time= 1.4min
# [CV 2/2; 78/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 2/2; 78/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time= 1.4min
# [CV 1/2; 79/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 1/2; 79/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time= 1.1min
# [CV 2/2; 79/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 2/2; 79/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time= 1.1min
# [CV 1/2; 80/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 1/2; 80/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time= 1.8min
# [CV 2/2; 80/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 2/2; 80/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time= 1.8min
# [CV 1/2; 81/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 1/2; 81/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time= 1.5min
# [CV 2/2; 81/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 2/2; 81/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time= 1.4min
# [CV 1/2; 82/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 1/2; 82/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time= 1.1min
# [CV 2/2; 82/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 2/2; 82/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time= 1.1min
# [CV 1/2; 83/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 1/2; 83/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time= 1.9min
# [CV 2/2; 83/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 2/2; 83/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time= 1.9min
# [CV 1/2; 84/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 1/2; 84/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time= 1.6min
# [CV 2/2; 84/192] START batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 2/2; 84/192] END batch_size=8, dr=0.1, epochs=5, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time= 1.5min
# [CV 1/2; 85/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 85/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time= 1.7min
# [CV 2/2; 85/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 85/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time= 1.7min
# [CV 1/2; 86/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=RMSprop
# [CV 1/2; 86/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=RMSprop; total time= 2.8min
# [CV 2/2; 86/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=RMSprop
# [CV 2/2; 86/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=RMSprop; total time= 2.8min
# [CV 1/2; 87/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=Adam
# [CV 1/2; 87/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=Adam; total time= 2.1min
# [CV 2/2; 87/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=Adam
# [CV 2/2; 87/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.01, optimizer=Adam; total time= 2.1min
# [CV 1/2; 88/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=SGD
# [CV 1/2; 88/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=SGD; total time= 1.6min
# [CV 2/2; 88/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=SGD
# [CV 2/2; 88/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=SGD; total time= 1.6min
# [CV 1/2; 89/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=RMSprop
# [CV 1/2; 89/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=RMSprop; total time= 2.7min
# [CV 2/2; 89/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=RMSprop
# [CV 2/2; 89/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=RMSprop; total time= 2.8min
# [CV 1/2; 90/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=Adam
# [CV 1/2; 90/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=Adam; total time= 2.1min
# [CV 2/2; 90/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=Adam
# [CV 2/2; 90/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=2, lr=0.1, optimizer=Adam; total time= 2.1min
# [CV 1/2; 91/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=SGD
# [CV 1/2; 91/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=SGD; total time= 1.7min
# [CV 2/2; 91/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=SGD
# [CV 2/2; 91/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=SGD; total time= 1.6min
# [CV 1/2; 92/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=RMSprop
# [CV 1/2; 92/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=RMSprop; total time= 2.8min
# [CV 2/2; 92/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=RMSprop
# [CV 2/2; 92/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=RMSprop; total time= 2.9min
# [CV 1/2; 93/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=Adam
# [CV 1/2; 93/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=Adam; total time= 2.3min
# [CV 2/2; 93/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=Adam
# [CV 2/2; 93/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.01, optimizer=Adam; total time= 2.3min
# [CV 1/2; 94/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=SGD
# [CV 1/2; 94/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=SGD; total time= 1.7min
# [CV 2/2; 94/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=SGD
# [CV 2/2; 94/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=SGD; total time= 1.7min
# [CV 1/2; 95/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=RMSprop
# [CV 1/2; 95/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=RMSprop; total time= 2.9min
# [CV 2/2; 95/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=RMSprop
# [CV 2/2; 95/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=RMSprop; total time= 2.9min
# [CV 1/2; 96/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=Adam
# [CV 1/2; 96/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=Adam; total time= 2.3min
# [CV 2/2; 96/192] START batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=Adam
# [CV 2/2; 96/192] END batch_size=8, dr=0.1, epochs=5, h_size=200, layer=4, lr=0.1, optimizer=Adam; total time= 2.2min
# [CV 1/2; 97/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 97/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time=  15.6s
# [CV 2/2; 97/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 97/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=SGD; total time=  18.2s
# [CV 1/2; 98/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 1/2; 98/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time=  25.0s
# [CV 2/2; 98/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop
# [CV 2/2; 98/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=RMSprop; total time=  23.9s
# [CV 1/2; 99/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 1/2; 99/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time=  20.0s
# [CV 2/2; 99/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam
# [CV 2/2; 99/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.01, optimizer=Adam; total time=  21.1s
# [CV 1/2; 100/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 1/2; 100/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time=  16.0s
# [CV 2/2; 100/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD
# [CV 2/2; 100/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=SGD; total time=  15.3s
# [CV 1/2; 101/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 1/2; 101/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time=  24.9s
# [CV 2/2; 101/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop
# [CV 2/2; 101/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=RMSprop; total time=  26.4s
# [CV 1/2; 102/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 1/2; 102/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time=  20.0s
# [CV 2/2; 102/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam
# [CV 2/2; 102/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=2, lr=0.1, optimizer=Adam; total time=  29.2s
# [CV 1/2; 103/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 1/2; 103/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time=  15.5s
# [CV 2/2; 103/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD
# [CV 2/2; 103/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=SGD; total time=  16.2s
# [CV 1/2; 104/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 1/2; 104/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time=  27.3s
# [CV 2/2; 104/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop
# [CV 2/2; 104/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=RMSprop; total time=  26.4s
# [CV 1/2; 105/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 1/2; 105/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time=  24.1s
# [CV 2/2; 105/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam
# [CV 2/2; 105/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.01, optimizer=Adam; total time=  21.0s
# [CV 1/2; 106/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 1/2; 106/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time=  17.0s
# [CV 2/2; 106/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD
# [CV 2/2; 106/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=SGD; total time=  18.6s
# [CV 1/2; 107/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 1/2; 107/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time=  25.6s
# [CV 2/2; 107/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop
# [CV 2/2; 107/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=RMSprop; total time=  26.5s
# [CV 1/2; 108/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 1/2; 108/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time=  22.8s
# [CV 2/2; 108/192] START batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam
# [CV 2/2; 108/192] END batch_size=16, dr=0.01, epochs=2, h_size=100, layer=4, lr=0.1, optimizer=Adam; total time=  21.7s
# [CV 1/2; 109/192] START batch_size=16, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 1/2; 109/192] END batch_size=16, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time=  25.4s
# [CV 2/2; 109/192] START batch_size=16, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD
# [CV 2/2; 109/192] END batch_size=16, dr=0.01, epochs=2, h_size=200, layer=2, lr=0.01, optimizer=SGD; total time=  27.1s
# ...
# 0.552500 (0.020100) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.573400 (0.012800) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.560400 (0.004200) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.583000 (0.004400) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.564600 (0.002400) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.568200 (0.005200) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.566900 (0.001500) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.564600 (0.002400) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.568200 (0.005200) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.569700 (0.005500) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.559900 (0.000900) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.550500 (0.002900) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.549300 (0.008300) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.559900 (0.000900) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.550500 (0.002900) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.583900 (0.004900) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.554100 (0.003500) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.562400 (0.004800) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.564300 (0.002700) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.554100 (0.003500) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.562400 (0.004800) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.565300 (0.001100) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.541000 (0.005400) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.536200 (0.003800) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.541900 (0.007500) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.541000 (0.005400) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.536200 (0.003800) with: {'batch_size': 8, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.542900 (0.001100) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.573600 (0.010000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.577400 (0.007400) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.574900 (0.005100) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.573600 (0.010000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.577400 (0.007400) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.557700 (0.007300) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.576900 (0.010700) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.552200 (0.003000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.550300 (0.005900) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.576900 (0.010700) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.552200 (0.003000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.538800 (0.001600) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.572700 (0.004100) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.574400 (0.005000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.574200 (0.004600) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.572700 (0.004100) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.574400 (0.005000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.565600 (0.003400) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.573000 (0.008800) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.542300 (0.005900) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.560800 (0.012000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.573000 (0.008800) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.542300 (0.005900) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.578600 (0.003000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.553600 (0.004000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.565300 (0.004900) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.563000 (0.001400) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.553600 (0.004000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.565300 (0.004900) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.576100 (0.003900) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.553000 (0.005000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.557600 (0.002400) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.542600 (0.003600) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.553000 (0.005000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.557600 (0.002400) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.574700 (0.001500) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.549200 (0.008000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.566400 (0.006400) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.561500 (0.001900) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.549200 (0.008000) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.566400 (0.006400) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.574000 (0.000200) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.544300 (0.003700) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.552500 (0.008700) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.559300 (0.002500) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.544300 (0.003700) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.552500 (0.008700) with: {'batch_size': 16, 'dr': 0.01, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.543500 (0.000700) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.583200 (0.006200) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.579800 (0.004000) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.575600 (0.005600) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.583200 (0.006200) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.579800 (0.004000) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.556200 (0.003200) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.572200 (0.015000) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.563900 (0.003700) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.548500 (0.011100) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.572200 (0.015000) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.563900 (0.003700) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.537700 (0.000700) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.571000 (0.003200) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.572900 (0.000900) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.573900 (0.002500) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.571000 (0.003200) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.572900 (0.000900) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.558700 (0.002100) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.565500 (0.018500) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.560000 (0.003000) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.560600 (0.014600) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.565500 (0.018500) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.560000 (0.003000) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 2, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.578200 (0.001600) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.557700 (0.001100) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.567200 (0.006200) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.567000 (0.003400) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.557700 (0.001100) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.567200 (0.006200) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.582500 (0.002700) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.558700 (0.000100) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.558600 (0.003800) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.547100 (0.001300) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.558700 (0.000100) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.558600 (0.003800) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 100, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.574300 (0.000500) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.551000 (0.004400) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.567100 (0.003500) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.565200 (0.001200) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.551000 (0.004400) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.567100 (0.003500) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 2, 'lr': 0.1, 'optimizer': 'Adam'}
# 0.576500 (0.004900) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'SGD'}
# 0.549900 (0.002100) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'RMSprop'}
# 0.543600 (0.008800) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.01, 'optimizer': 'Adam'}
# 0.542000 (0.008200) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'SGD'}
# 0.549900 (0.002100) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'RMSprop'}
# 0.543600 (0.008800) with: {'batch_size': 16, 'dr': 0.1, 'epochs': 5, 'h_size': 200, 'layer': 4, 'lr': 0.1, 'optimizer': 'Adam'}

# %% [markdown]
# ###  The best MLP model is
# ###  'batch_size': 8, 'dr': 0.01, 'epochs': 5, 'h_size': 100, 'layer': 2, 'lr': 0.01, 'optimizer': 'SGD'
# ### The accuracy is 0.5851
