# %% [markdown]
# ## Import Libraries

# %%
import os
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english'))
ps = PorterStemmer()
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from itertools import chain
from sklearn.metrics import accuracy_score, f1_score
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

stopwords = set(stopwords.words("english"))
ps = PorterStemmer()

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### A. Load the data

# %%
def load_data(split_name='train', columns=['text', 'stars']):
    try:
        print(f"select [{', '.join(columns)}] columns from the {split_name} split")
        df = pd.read_csv(f'data_2021_spring/{split_name}.csv')
        df = df.loc[:,columns]
        print("succeed!")
        return df
    except:
        print("Failed, then try to ")
        print(f"select all columns from the {split_name} split")
        df = pd.read_csv(f'data_2021_spring/{split_name}.csv')
        return df

# %%
train_df = load_data('train', columns=['text'])
# Out:
# select [text] columns from the train split
# succeed!

# %%
train_df.head()
# Out:
#                                                 text
# 0  Nice to have a diner still around. Food was go...
# 1  Tried this a while back, got the fried chicken...
# 2  I expected more pork selections on menu. Food ...
# 3  YUMMY!!! This place is phenomenal. It is Price...
# 4  The Truffle Macaroni & Cheese and Potatoes Au ...

# %%
test_df = load_data('test')
# Out:
# select [text, stars] columns from the test split
# Failed, then try to
# select all columns from the test split

# %%
len(test_df)
# Out:
# 2000

# %% [markdown]
# ## 2. Preprocessing

# %%
def lower(s):
    """
    :param s: a string.
    return a string with lower characters
    Note that we allow the input to be nested string of a list.
    e.g.
    Input: 'Text mining is to identify useful information.'
    Output: 'text mining is to identify useful information.'
    """
    if isinstance(s, list):
        return [lower(t) for t in s]
    if isinstance(s, str):
        return s.lower()
    else:
        raise NotImplementedError("unknown datatype")


def tokenize(text):
    """
    :param text: a doc with multiple sentences, type: str
    return a word list, type: list
    e.g.
    Input: 'Text mining is to identify useful information.'
    Output: ['Text', 'mining', 'is', 'to', 'identify', 'useful', 'information', '.']
    """
    return nltk.word_tokenize(text)


def stem(tokens):
    """
    :param tokens: a list of tokens, type: list
    return a list of stemmed words, type: list
    e.g.
    Input: ['Text', 'mining', 'is', 'to', 'identify', 'useful', 'information', '.']
    Output: ['text', 'mine', 'is', 'to', 'identifi', 'use', 'inform', '.']
    """
    ### equivalent code
    # results = list()
    # for token in tokens:
    #     results.append(ps.stem(token))
    # return results

    return [ps.stem(token) for token in tokens]

def n_gram(tokens, n=1):
    """
    :param tokens: a list of tokens, type: list
    :param n: the corresponding n-gram, type: int
    return a list of n-gram tokens, type: list
    e.g.
    Input: ['text', 'mine', 'is', 'to', 'identifi', 'use', 'inform', '.'], 2
    Output: ['text mine', 'mine is', 'is to', 'to identifi', 'identifi use', 'use inform', 'inform .']
    """
    if n == 1:
        return tokens
    else:
        results = list()
        for i in range(len(tokens)-n+1):
            # tokens[i:i+n] will return a sublist from i th to i+n th (i+n th is not included)
            results.append(" ".join(tokens[i:i+n]))
        return results

def filter_stopwords(tokens):
    """
    :param tokens: a list of tokens, type: list
    return a list of filtered tokens, type: list
    e.g.
    Input: ['text', 'mine', 'is', 'to', 'identifi', 'use', 'inform', '.']
    Output: ['text', 'mine', 'identifi', 'use', 'inform', '.']
    """
    ### equivalent code
    # results = list()
    # for token in tokens:
    #     if token not in stopwords and not token.isnumeric():
    #         results.append(token)
    # return results

    return [token for token in tokens if token not in stopwords and not token.isnumeric()]

import numpy as np

def get_onehot_vector(feats, feats_dict):
    """
    :param data: a list of features, type: list
    :param feats_dict: a dict from features to indices, type: dict
    return a feature vector,
    """
    # initialize the vector as all zeros
    vector = np.zeros(len(feats_dict), dtype=np.float)
    for f in feats:
        # get the feature index, return -1 if the feature is not existed
        f_idx = feats_dict.get(f, -1)
        if f_idx != -1:
            # set the corresponding element as 1
            vector[f_idx] = 1
    return vector

# %% [markdown]
# ## 3. Baselines

# %%
train_df = load_data('train')
valid_df = load_data('valid')
# Out:
# select [text, stars] columns from the train split
# succeed!
# select [text, stars] columns from the valid split
# succeed!

# %% [markdown]
# The split above is what we have done for you. You can use the data as you like.

# %%
x_train = train_df['text']
y_train = train_df['stars']

# %%
#grid with only analyzers == word and stopwords
tfidf = TfidfVectorizer(tokenizer=tokenize)
lr = LogisticRegression()
steps = [('tfidf', tfidf),('lr', lr)]
pipe = Pipeline(steps)
    # Creating Parameter Space
# parameter for tdidf  
analyzer  = ['word']
ngram_range = [(1,1),(1,2),(2,2)]
norm = ['l1', 'l2']
stop_words=['english','None']
# parameter for Logistic Regression 
penalty = ['l1', 'l2', 'elasticnet', 'none']
random_state = [42]
n_jobs = [-1]
C = np.logspace(-3,3,3)
solver = ['saga']


    # Creating a dictionary of all the parameter options 
parameters = dict(tfidf__analyzer=analyzer,
                  tfidf__ngram_range=ngram_range,
                  tfidf__norm=norm,
                  tfidf__stop_words=stop_words,
                  lr__penalty=penalty,
                  lr__random_state=random_state,
                  lr__n_jobs=n_jobs,
                  lr__solver=solver,
                  lr__C=C
                 )

cv = 5

# %%
# %%time
    # Creating a grid search object
model = GridSearchCV(pipe, parameters,scoring= 'accuracy', cv=cv, n_jobs = -1, verbose = 30)
    # Fitting the grid search
model_result=model.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   16.1s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   48.0s
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:   48.1s
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 148 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 149 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 151 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done 152 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 153 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 155 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 157 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 159 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 161 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 162 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 163 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 164 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 165 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 166 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 167 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 169 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 170 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 171 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 172 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 174 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 175 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 177 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 178 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 179 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 180 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 182 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 183 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 185 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 186 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 187 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 188 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 189 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 190 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 191 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 193 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 194 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 195 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 197 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 198 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 199 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 200 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 201 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 203 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 204 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 206 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 207 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 208 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 209 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 210 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 211 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 212 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 214 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 215 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 217 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 218 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 219 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 220 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 222 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 223 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 224 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 226 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 227 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 228 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 229 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 230 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 231 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 232 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 233 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 235 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 236 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 237 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 239 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 240 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 241 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done 242 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 243 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 245 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 246 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 247 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 249 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 251 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 253 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 255 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 259 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 261 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 265 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 267 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 268 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 269 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done 270 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 271 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 274 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 275 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 276 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 277 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 278 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 279 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 281 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 282 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 283 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 285 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 286 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 287 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done 288 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done 289 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 290 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 291 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=-1)]: Done 292 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 293 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 294 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 295 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 296 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 299 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 301 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 302 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 303 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 304 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 306 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 307 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 309 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 310 tasks      | elapsed: 14.4min
# [Parallel(n_jobs=-1)]: Done 311 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 312 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 313 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 314 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 315 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 316 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 317 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 318 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 319 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 321 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 322 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 323 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 324 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 325 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 326 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 327 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done 328 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done 329 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 331 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done 332 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 333 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 334 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 336 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 337 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 338 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 339 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done 340 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 342 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 344 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 345 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 346 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 347 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 348 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 350 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done 351 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done 352 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 353 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 354 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 355 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 356 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 358 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 359 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 360 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done 361 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 362 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 363 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 364 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 365 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 366 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 367 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 369 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 371 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 372 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 373 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 374 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 375 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 377 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 378 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 379 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 380 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done 381 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done 382 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 383 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 385 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 386 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 387 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 388 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 389 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 390 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 391 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 392 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 393 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 394 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 395 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 396 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 397 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 398 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 399 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 400 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 401 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 402 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 403 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 404 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 405 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 406 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 407 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 408 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 409 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 411 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 412 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 414 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 415 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 416 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 417 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done 418 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 419 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 421 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 423 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 424 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 425 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 427 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 428 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=-1)]: Done 429 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 430 tasks      | elapsed: 18.1min
# [Parallel(n_jobs=-1)]: Done 431 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 432 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 433 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 435 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 436 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 437 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 438 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done 439 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=-1)]: Done 440 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done 441 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 443 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 445 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 447 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 448 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done 450 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 451 tasks      | elapsed: 19.4min
# [Parallel(n_jobs=-1)]: Done 452 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 453 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 454 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 455 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 456 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 457 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 458 tasks      | elapsed: 19.6min
# [Parallel(n_jobs=-1)]: Done 459 tasks      | elapsed: 19.8min
# [Parallel(n_jobs=-1)]: Done 460 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 461 tasks      | elapsed: 20.0min
# [Parallel(n_jobs=-1)]: Done 462 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 463 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 464 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 465 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 467 tasks      | elapsed: 20.1min
# [Parallel(n_jobs=-1)]: Done 468 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=-1)]: Done 469 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done 470 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done 471 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done 472 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 474 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 475 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 476 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 477 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 478 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done 479 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=-1)]: Done 480 tasks      | elapsed: 21.0min
# [Parallel(n_jobs=-1)]: Done 481 tasks      | elapsed: 29.6min
# [Parallel(n_jobs=-1)]: Done 482 tasks      | elapsed: 29.7min
# [Parallel(n_jobs=-1)]: Done 483 tasks      | elapsed: 29.7min
# [Parallel(n_jobs=-1)]: Done 484 tasks      | elapsed: 29.7min
# [Parallel(n_jobs=-1)]: Done 485 tasks      | elapsed: 29.7min
# [Parallel(n_jobs=-1)]: Done 486 tasks      | elapsed: 29.7min
# [Parallel(n_jobs=-1)]: Done 487 tasks      | elapsed: 29.7min
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed: 29.8min
# [Parallel(n_jobs=-1)]: Done 489 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=-1)]: Done 490 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=-1)]: Done 491 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=-1)]: Done 492 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=-1)]: Done 493 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=-1)]: Done 494 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=-1)]: Done 495 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=-1)]: Done 496 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=-1)]: Done 497 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=-1)]: Done 498 tasks      | elapsed: 38.4min
# [Parallel(n_jobs=-1)]: Done 499 tasks      | elapsed: 43.1min
# [Parallel(n_jobs=-1)]: Done 500 tasks      | elapsed: 43.2min
# [Parallel(n_jobs=-1)]: Done 501 tasks      | elapsed: 105.9min
# [Parallel(n_jobs=-1)]: Done 502 tasks      | elapsed: 107.4min
# [Parallel(n_jobs=-1)]: Done 503 tasks      | elapsed: 107.4min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed: 107.4min
# [Parallel(n_jobs=-1)]: Done 505 tasks      | elapsed: 107.4min
# [Parallel(n_jobs=-1)]: Done 506 tasks      | elapsed: 107.4min
# [Parallel(n_jobs=-1)]: Done 507 tasks      | elapsed: 107.4min
# [Parallel(n_jobs=-1)]: Done 508 tasks      | elapsed: 112.3min
# [Parallel(n_jobs=-1)]: Done 509 tasks      | elapsed: 112.5min
# [Parallel(n_jobs=-1)]: Done 510 tasks      | elapsed: 148.0min
# [Parallel(n_jobs=-1)]: Done 511 tasks      | elapsed: 152.8min
# [Parallel(n_jobs=-1)]: Done 512 tasks      | elapsed: 152.9min
# [Parallel(n_jobs=-1)]: Done 513 tasks      | elapsed: 152.9min
# [Parallel(n_jobs=-1)]: Done 514 tasks      | elapsed: 152.9min
# [Parallel(n_jobs=-1)]: Done 515 tasks      | elapsed: 152.9min
# [Parallel(n_jobs=-1)]: Done 516 tasks      | elapsed: 152.9min
# [Parallel(n_jobs=-1)]: Done 517 tasks      | elapsed: 152.9min
# [Parallel(n_jobs=-1)]: Done 518 tasks      | elapsed: 173.2min
# [Parallel(n_jobs=-1)]: Done 519 tasks      | elapsed: 184.4min
# [Parallel(n_jobs=-1)]: Done 520 tasks      | elapsed: 188.6min
# [Parallel(n_jobs=-1)]: Done 521 tasks      | elapsed: 233.0min
# [Parallel(n_jobs=-1)]: Done 522 tasks      | elapsed: 255.1min
# [Parallel(n_jobs=-1)]: Done 523 tasks      | elapsed: 255.1min
# [Parallel(n_jobs=-1)]: Done 524 tasks      | elapsed: 255.1min
# [Parallel(n_jobs=-1)]: Done 525 tasks      | elapsed: 255.1min
# [Parallel(n_jobs=-1)]: Done 526 tasks      | elapsed: 255.1min
# [Parallel(n_jobs=-1)]: Done 527 tasks      | elapsed: 255.1min
# [Parallel(n_jobs=-1)]: Done 528 tasks      | elapsed: 268.3min
# [Parallel(n_jobs=-1)]: Done 529 tasks      | elapsed: 273.7min
# [Parallel(n_jobs=-1)]: Done 530 tasks      | elapsed: 297.7min
# [Parallel(n_jobs=-1)]: Done 531 tasks      | elapsed: 310.8min
# [Parallel(n_jobs=-1)]: Done 532 tasks      | elapsed: 316.1min
# [Parallel(n_jobs=-1)]: Done 533 tasks      | elapsed: 316.1min
# [Parallel(n_jobs=-1)]: Done 534 tasks      | elapsed: 316.1min
# [Parallel(n_jobs=-1)]: Done 535 tasks      | elapsed: 316.1min
# [Parallel(n_jobs=-1)]: Done 536 tasks      | elapsed: 316.1min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed: 316.1min
# [Parallel(n_jobs=-1)]: Done 538 tasks      | elapsed: 316.3min
# [Parallel(n_jobs=-1)]: Done 539 tasks      | elapsed: 316.6min
# [Parallel(n_jobs=-1)]: Done 540 tasks      | elapsed: 316.9min
# [Parallel(n_jobs=-1)]: Done 541 tasks      | elapsed: 317.2min
# [Parallel(n_jobs=-1)]: Done 542 tasks      | elapsed: 317.5min
# [Parallel(n_jobs=-1)]: Done 543 tasks      | elapsed: 317.5min
# [Parallel(n_jobs=-1)]: Done 544 tasks      | elapsed: 317.5min
# [Parallel(n_jobs=-1)]: Done 545 tasks      | elapsed: 317.5min
# [Parallel(n_jobs=-1)]: Done 546 tasks      | elapsed: 317.5min
# [Parallel(n_jobs=-1)]: Done 547 tasks      | elapsed: 317.5min
# [Parallel(n_jobs=-1)]: Done 548 tasks      | elapsed: 317.8min
# [Parallel(n_jobs=-1)]: Done 549 tasks      | elapsed: 317.8min
# [Parallel(n_jobs=-1)]: Done 550 tasks      | elapsed: 318.0min
# [Parallel(n_jobs=-1)]: Done 551 tasks      | elapsed: 318.1min
# [Parallel(n_jobs=-1)]: Done 552 tasks      | elapsed: 318.3min
# [Parallel(n_jobs=-1)]: Done 553 tasks      | elapsed: 318.3min
# [Parallel(n_jobs=-1)]: Done 554 tasks      | elapsed: 318.3min
# [Parallel(n_jobs=-1)]: Done 555 tasks      | elapsed: 318.3min
# [Parallel(n_jobs=-1)]: Done 556 tasks      | elapsed: 318.3min
# [Parallel(n_jobs=-1)]: Done 557 tasks      | elapsed: 318.3min
# [Parallel(n_jobs=-1)]: Done 558 tasks      | elapsed: 318.3min
# [Parallel(n_jobs=-1)]: Done 559 tasks      | elapsed: 318.8min
# [Parallel(n_jobs=-1)]: Done 560 tasks      | elapsed: 318.8min
# [Parallel(n_jobs=-1)]: Done 561 tasks      | elapsed: 319.3min
# [Parallel(n_jobs=-1)]: Done 562 tasks      | elapsed: 319.3min
# [Parallel(n_jobs=-1)]: Done 563 tasks      | elapsed: 319.3min
# [Parallel(n_jobs=-1)]: Done 564 tasks      | elapsed: 319.3min
# [Parallel(n_jobs=-1)]: Done 565 tasks      | elapsed: 319.3min
# [Parallel(n_jobs=-1)]: Done 566 tasks      | elapsed: 319.3min
# [Parallel(n_jobs=-1)]: Done 567 tasks      | elapsed: 319.3min
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed: 319.8min
# [Parallel(n_jobs=-1)]: Done 569 tasks      | elapsed: 319.8min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed: 320.2min
# [Parallel(n_jobs=-1)]: Done 571 tasks      | elapsed: 320.3min
# [Parallel(n_jobs=-1)]: Done 572 tasks      | elapsed: 320.7min
# [Parallel(n_jobs=-1)]: Done 573 tasks      | elapsed: 320.7min
# [Parallel(n_jobs=-1)]: Done 574 tasks      | elapsed: 320.7min
# [Parallel(n_jobs=-1)]: Done 575 tasks      | elapsed: 320.7min
# [Parallel(n_jobs=-1)]: Done 576 tasks      | elapsed: 320.7min
# [Parallel(n_jobs=-1)]: Done 577 tasks      | elapsed: 320.7min
# [Parallel(n_jobs=-1)]: Done 578 tasks      | elapsed: 320.8min
# [Parallel(n_jobs=-1)]: Done 579 tasks      | elapsed: 321.1min
# [Parallel(n_jobs=-1)]: Done 580 tasks      | elapsed: 321.2min
# [Parallel(n_jobs=-1)]: Done 581 tasks      | elapsed: 321.5min
# [Parallel(n_jobs=-1)]: Done 582 tasks      | elapsed: 321.6min
# [Parallel(n_jobs=-1)]: Done 583 tasks      | elapsed: 321.6min
# [Parallel(n_jobs=-1)]: Done 584 tasks      | elapsed: 321.6min
# [Parallel(n_jobs=-1)]: Done 585 tasks      | elapsed: 321.6min
# [Parallel(n_jobs=-1)]: Done 586 tasks      | elapsed: 321.6min
# [Parallel(n_jobs=-1)]: Done 587 tasks      | elapsed: 321.6min
# [Parallel(n_jobs=-1)]: Done 588 tasks      | elapsed: 322.0min
# [Parallel(n_jobs=-1)]: Done 589 tasks      | elapsed: 322.0min
# [Parallel(n_jobs=-1)]: Done 590 tasks      | elapsed: 322.4min
# [Parallel(n_jobs=-1)]: Done 591 tasks      | elapsed: 322.4min
# [Parallel(n_jobs=-1)]: Done 592 tasks      | elapsed: 322.8min
# [Parallel(n_jobs=-1)]: Done 593 tasks      | elapsed: 322.8min
# [Parallel(n_jobs=-1)]: Done 594 tasks      | elapsed: 322.8min
# [Parallel(n_jobs=-1)]: Done 595 tasks      | elapsed: 322.8min
# [Parallel(n_jobs=-1)]: Done 596 tasks      | elapsed: 322.8min
# [Parallel(n_jobs=-1)]: Done 597 tasks      | elapsed: 322.8min
# [Parallel(n_jobs=-1)]: Done 598 tasks      | elapsed: 322.8min
# [Parallel(n_jobs=-1)]: Done 599 tasks      | elapsed: 322.9min
# [Parallel(n_jobs=-1)]: Done 600 tasks      | elapsed: 323.0min
# [Parallel(n_jobs=-1)]: Done 601 tasks      | elapsed: 323.1min
# [Parallel(n_jobs=-1)]: Done 602 tasks      | elapsed: 323.2min
# [Parallel(n_jobs=-1)]: Done 603 tasks      | elapsed: 323.2min
# [Parallel(n_jobs=-1)]: Done 604 tasks      | elapsed: 323.2min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed: 323.2min
# [Parallel(n_jobs=-1)]: Done 606 tasks      | elapsed: 323.2min
# [Parallel(n_jobs=-1)]: Done 607 tasks      | elapsed: 323.2min
# [Parallel(n_jobs=-1)]: Done 608 tasks      | elapsed: 323.3min
# [Parallel(n_jobs=-1)]: Done 609 tasks      | elapsed: 323.4min
# [Parallel(n_jobs=-1)]: Done 610 tasks      | elapsed: 323.5min
# [Parallel(n_jobs=-1)]: Done 611 tasks      | elapsed: 323.6min
# [Parallel(n_jobs=-1)]: Done 612 tasks      | elapsed: 323.7min
# [Parallel(n_jobs=-1)]: Done 613 tasks      | elapsed: 323.7min
# [Parallel(n_jobs=-1)]: Done 614 tasks      | elapsed: 323.7min
# [Parallel(n_jobs=-1)]: Done 615 tasks      | elapsed: 323.7min
# [Parallel(n_jobs=-1)]: Done 616 tasks      | elapsed: 323.7min
# [Parallel(n_jobs=-1)]: Done 617 tasks      | elapsed: 323.7min
# [Parallel(n_jobs=-1)]: Done 618 tasks      | elapsed: 323.8min
# [Parallel(n_jobs=-1)]: Done 619 tasks      | elapsed: 323.9min
# [Parallel(n_jobs=-1)]: Done 620 tasks      | elapsed: 324.0min
# [Parallel(n_jobs=-1)]: Done 621 tasks      | elapsed: 324.2min
# [Parallel(n_jobs=-1)]: Done 622 tasks      | elapsed: 324.2min
# [Parallel(n_jobs=-1)]: Done 623 tasks      | elapsed: 324.2min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 324.2min
# [Parallel(n_jobs=-1)]: Done 625 tasks      | elapsed: 324.2min
# [Parallel(n_jobs=-1)]: Done 626 tasks      | elapsed: 324.2min
# [Parallel(n_jobs=-1)]: Done 627 tasks      | elapsed: 324.2min
# [Parallel(n_jobs=-1)]: Done 628 tasks      | elapsed: 324.4min
# [Parallel(n_jobs=-1)]: Done 629 tasks      | elapsed: 324.4min
# [Parallel(n_jobs=-1)]: Done 630 tasks      | elapsed: 324.6min
# [Parallel(n_jobs=-1)]: Done 631 tasks      | elapsed: 324.7min
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 324.8min
# [Parallel(n_jobs=-1)]: Done 633 tasks      | elapsed: 324.8min
# [Parallel(n_jobs=-1)]: Done 634 tasks      | elapsed: 324.8min
# [Parallel(n_jobs=-1)]: Done 635 tasks      | elapsed: 324.8min
# [Parallel(n_jobs=-1)]: Done 636 tasks      | elapsed: 324.8min
# [Parallel(n_jobs=-1)]: Done 637 tasks      | elapsed: 324.8min
# [Parallel(n_jobs=-1)]: Done 638 tasks      | elapsed: 324.9min
# [Parallel(n_jobs=-1)]: Done 639 tasks      | elapsed: 325.0min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 325.1min
# [Parallel(n_jobs=-1)]: Done 641 tasks      | elapsed: 325.3min
# [Parallel(n_jobs=-1)]: Done 642 tasks      | elapsed: 325.3min
# [Parallel(n_jobs=-1)]: Done 643 tasks      | elapsed: 325.3min
# [Parallel(n_jobs=-1)]: Done 644 tasks      | elapsed: 325.3min
# [Parallel(n_jobs=-1)]: Done 645 tasks      | elapsed: 325.3min
# [Parallel(n_jobs=-1)]: Done 646 tasks      | elapsed: 325.3min
# [Parallel(n_jobs=-1)]: Done 647 tasks      | elapsed: 325.3min
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed: 325.5min
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed: 325.5min
# [Parallel(n_jobs=-1)]: Done 650 tasks      | elapsed: 325.7min
# [Parallel(n_jobs=-1)]: Done 651 tasks      | elapsed: 325.7min
# [Parallel(n_jobs=-1)]: Done 652 tasks      | elapsed: 325.9min
# [Parallel(n_jobs=-1)]: Done 653 tasks      | elapsed: 325.9min
# [Parallel(n_jobs=-1)]: Done 654 tasks      | elapsed: 325.9min
# [Parallel(n_jobs=-1)]: Done 655 tasks      | elapsed: 325.9min
# [Parallel(n_jobs=-1)]: Done 656 tasks      | elapsed: 325.9min
# [Parallel(n_jobs=-1)]: Done 657 tasks      | elapsed: 325.9min
# [Parallel(n_jobs=-1)]: Done 658 tasks      | elapsed: 325.9min
# [Parallel(n_jobs=-1)]: Done 659 tasks      | elapsed: 326.2min
# [Parallel(n_jobs=-1)]: Done 660 tasks      | elapsed: 326.2min
# [Parallel(n_jobs=-1)]: Done 661 tasks      | elapsed: 326.4min
# [Parallel(n_jobs=-1)]: Done 662 tasks      | elapsed: 326.5min
# [Parallel(n_jobs=-1)]: Done 663 tasks      | elapsed: 326.5min
# [Parallel(n_jobs=-1)]: Done 664 tasks      | elapsed: 326.5min
# [Parallel(n_jobs=-1)]: Done 665 tasks      | elapsed: 326.5min
# [Parallel(n_jobs=-1)]: Done 666 tasks      | elapsed: 326.5min
# [Parallel(n_jobs=-1)]: Done 667 tasks      | elapsed: 326.5min
# [Parallel(n_jobs=-1)]: Done 668 tasks      | elapsed: 326.7min
# [Parallel(n_jobs=-1)]: Done 669 tasks      | elapsed: 326.8min
# [Parallel(n_jobs=-1)]: Done 670 tasks      | elapsed: 327.0min
# [Parallel(n_jobs=-1)]: Done 671 tasks      | elapsed: 327.0min
# [Parallel(n_jobs=-1)]: Done 672 tasks      | elapsed: 327.2min
# [Parallel(n_jobs=-1)]: Done 673 tasks      | elapsed: 327.3min
# [Parallel(n_jobs=-1)]: Done 674 tasks      | elapsed: 327.3min
# [Parallel(n_jobs=-1)]: Done 675 tasks      | elapsed: 327.3min
# [Parallel(n_jobs=-1)]: Done 676 tasks      | elapsed: 327.3min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed: 327.3min
# [Parallel(n_jobs=-1)]: Done 678 tasks      | elapsed: 327.3min
# [Parallel(n_jobs=-1)]: Done 679 tasks      | elapsed: 327.7min
# [Parallel(n_jobs=-1)]: Done 680 tasks      | elapsed: 327.8min
# [Parallel(n_jobs=-1)]: Done 681 tasks      | elapsed: 328.2min
# [Parallel(n_jobs=-1)]: Done 682 tasks      | elapsed: 328.3min
# [Parallel(n_jobs=-1)]: Done 683 tasks      | elapsed: 328.3min
# [Parallel(n_jobs=-1)]: Done 684 tasks      | elapsed: 328.3min
# [Parallel(n_jobs=-1)]: Done 685 tasks      | elapsed: 328.3min
# [Parallel(n_jobs=-1)]: Done 686 tasks      | elapsed: 328.3min
# [Parallel(n_jobs=-1)]: Done 687 tasks      | elapsed: 328.3min
# [Parallel(n_jobs=-1)]: Done 688 tasks      | elapsed: 328.7min
# [Parallel(n_jobs=-1)]: Done 689 tasks      | elapsed: 328.8min
# [Parallel(n_jobs=-1)]: Done 690 tasks      | elapsed: 329.1min
# [Parallel(n_jobs=-1)]: Done 691 tasks      | elapsed: 329.2min
# [Parallel(n_jobs=-1)]: Done 692 tasks      | elapsed: 329.6min
# [Parallel(n_jobs=-1)]: Done 693 tasks      | elapsed: 329.6min
# [Parallel(n_jobs=-1)]: Done 694 tasks      | elapsed: 329.6min
# [Parallel(n_jobs=-1)]: Done 695 tasks      | elapsed: 329.6min
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed: 329.6min
# [Parallel(n_jobs=-1)]: Done 697 tasks      | elapsed: 329.6min
# [Parallel(n_jobs=-1)]: Done 698 tasks      | elapsed: 329.7min
# [Parallel(n_jobs=-1)]: Done 699 tasks      | elapsed: 330.0min
# [Parallel(n_jobs=-1)]: Done 700 tasks      | elapsed: 330.1min
# [Parallel(n_jobs=-1)]: Done 701 tasks      | elapsed: 330.4min
# [Parallel(n_jobs=-1)]: Done 702 tasks      | elapsed: 330.5min
# [Parallel(n_jobs=-1)]: Done 703 tasks      | elapsed: 330.5min
# [Parallel(n_jobs=-1)]: Done 704 tasks      | elapsed: 330.5min
# [Parallel(n_jobs=-1)]: Done 705 tasks      | elapsed: 330.5min
# [Parallel(n_jobs=-1)]: Done 706 tasks      | elapsed: 330.5min
# [Parallel(n_jobs=-1)]: Done 707 tasks      | elapsed: 330.5min
# [Parallel(n_jobs=-1)]: Done 708 tasks      | elapsed: 330.8min
# [Parallel(n_jobs=-1)]: Done 709 tasks      | elapsed: 330.9min
# [Parallel(n_jobs=-1)]: Done 710 tasks      | elapsed: 331.2min
# [Parallel(n_jobs=-1)]: Done 711 tasks      | elapsed: 331.3min
# [Parallel(n_jobs=-1)]: Done 712 tasks      | elapsed: 331.6min
# [Parallel(n_jobs=-1)]: Done 713 tasks      | elapsed: 331.6min
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed: 349.6min finished
# Wall time: 5h 49min 49s

# %%
print("Best: %f using %s" % (model_result.best_score_, model_result.best_params_))
# Out:
# Best: 0.577000 using {'lr__C': 1.0, 'lr__n_jobs': -1, 'lr__penalty': 'l2', 'lr__random_state': 42, 'lr__solver': 'saga', 'tfidf__analyzer': 'word', 'tfidf__ngram_range': (1, 2), 'tfidf__norm': 'l2', 'tfidf__stop_words': 'english'}

# %%
x_valid = valid_df['text']
y_valid = valid_df['stars']
tfidf = TfidfVectorizer(tokenizer=tokenize,analyzer='word',norm='l2',ngram_range=(1,2),stop_words='english')
lr = LogisticRegression(C=1.0,n_jobs=-1,penalty='l2',random_state=42,solver='saga')
steps = [('tfidf', tfidf),('lr', lr)]
pipe = Pipeline(steps)
pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_valid)
print(classification_report(y_valid, y_pred))
print("\n\n")
print(confusion_matrix(y_valid, y_pred))
print('accuracy', np.mean(y_valid == y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.68      0.88      0.76       517
#            2       0.43      0.15      0.23       278
#            3       0.42      0.43      0.42       344
#            4       0.51      0.56      0.53       427
#            5       0.72      0.68      0.70       434
#
#     accuracy                           0.59      2000
#    macro avg       0.55      0.54      0.53      2000
# weighted avg       0.57      0.59      0.57      2000
#
#
#
#
# [[455  14  28  11   9]
#  [122  43  83  25   5]
#  [ 52  35 147  95  15]
#  [ 22   5  75 237  88]
#  [ 22   4  15  98 295]]
# accuracy 0.5885

# %% [markdown]
# ###  The best Logistic Regression model is
# ###  Logistic Regression parameter: 'Inverse regularization parameter': 1.0 'lr__penalty': 'l2', 'lr__solver': 'saga'
# ###  TDIDF parameter:'tfidf__analyzer': 'word', 'tfidf__ngram_range': (1, 2), 'tfidf__norm': 'l2', 'tfidf__stop_words': 'english'
# ### The accuracy is 0.5770
